# %%
with open('obscodes.txt', 'r') as f:
    lines = f.readlines()
    for line in lines[1:]:

        lon_str = line[5:13]
        lat_str = line[13:21]
        elev_str = line[21:30]



        if lon_str.strip() == '':
            print(f'{line.strip()}')
            name = line[30:]
            continue
# Out:
# 245                           Spitzer Space Telescope
# 247                           Roving Observer
# 249                           SOHO
# 250                           Hubble Space Telescope
# 258                           Gaia
# 270                           Unistellar Network, Roving Observer
# 273                           Euclid
# 274                           James Webb Space Telescope
# 275                           Non-geocentric Occultation Observation
# C49                           STEREO-A
# C50                           STEREO-B
# C51                           WISE
# C52                           Swift
# C53                           NEOSSat
# C54                           New Horizons
# C55                           Kepler
# C56                           LISA-Pathfinder
# C57                           TESS
# C58                           NEO Surveyor
# C59                           Yangwang-1

# %%
'''
C51: WISE: -163
C58: NEO Surveyor: -33
C49: STEREO-A: -234
C50: STEREO-B: -235
245: Spitzer Space Telescope: -79
C54: New Horizons: -98
250: Hubble Space Telescope: -48
274: James Webb Space Telescope: -170
C55: Kepler: -227
Lucy: -49
'''

# %%
'''
247                           Roving Observer
270                           Unistellar Network, Roving Observer
275                           Non-geocentric Occultation Observation

249                           SOHO
258                           Gaia
273                           Euclid
C52                           Swift
C53                           NEOSSat
C56                           LISA-Pathfinder
C57                           TESS
C59                           Yangwang-1
'''
