# %%
from spacerocks.time import Time

# %%
t = Time.now()

# %%
t.calendar()
# Out:
# '11 Jul 2024'

# %%
t.timescale, t.timeformat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t.timescale, t.timeformat
#
# AttributeError: 'builtins.Time' object has no attribute 'timeformat'

# %%
t.epoch
# Out:
# 2460503.2451967592

# %%
t.to_tdb()

# %%
print(t)
# Out:
# Time: 2460351.4572012154 tdb jd

# %%
t2 = Time(epoch=2451545.0, timescale='tdb', format='jd')

# %%
t2
# Out:
# Time: 2451545 tdb jd
