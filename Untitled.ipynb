# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

from matplotlib.colors import LogNorm

# %%
import easyaccess as ea

# %%
db = ea.connect(section='umtno')
# Out:
# Connecting to DB ** umtno ** ...

# %%
result = db.query_to_pandas(f"SELECT * FROM umtno.SS_OBJECT WHERE objid='a3de8c72fa2d47f4b5ef192dac3ea867'")
result
# Out:
# Empty DataFrame
# Columns: [OBJID, FLUX_ISO, FLUXERR_ISO, FLUX_AUTO, FLUXERR_AUTO, MAG_AUTO, MAGERR_AUTO, ISOAREA_IMAGE, X_IMAGE, Y_IMAGE, RA, DEC, AWIN_IMAGE, BWIN_IMAGE, THETAWIN_IMAGE, ERRAWIN_IMAGE, ERRBWIN_IMAGE, ERRTHETAWIN_IMAGE, FWHM_IMAGE, FWHM_WORLD, ELLIPTICITY, FLUX_RADIUS, ELLIP_WIN, SNR, SS_RUNID, RA_RATE, DEC_RATE, CCD, FILENAME]
# Index: []

# %%
im = fits.getdata('/Users/kjnapier/Desktop/5217e5987f734d6f8dd80f6bf02a517d.fits')
im += -np.min(im)
im /= np.max(im)
#im -= np.random.rand(51, 51)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-1679fdcfa00c> in <module>
# ----> 1 im = fits.getdata('/Users/kjnapier/Desktop/5217e5987f734d6f8dd80f6bf02a517d.fits')
#       2 im += -np.min(im)
#       3 im /= np.max(im)
#       4 #im -= np.random.rand(51, 51)
#
# /usr/local/bin/anaconda/envs/spacerocks/lib/python3.8/site-packages/astropy/io/fits/convenience.py in getdata(filename, header, lower, upper, view, *args, **kwargs)
#     192     mode, closed = _get_file_mode(filename)
#     193
# --> 194     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     195     try:
#     196         hdu = hdulist[extidx]
#
# /usr/local/bin/anaconda/envs/spacerocks/lib/python3.8/site-packages/astropy/io/fits/convenience.py in _getext(filename, mode, ext, extname, extver, *args, **kwargs)
# ...

# %%
from scipy import ndimage

# %%
plt.imshow(ndimage.gaussian_filter(im, 3), cmap='viridis')

# %%
abs(im_fft)
